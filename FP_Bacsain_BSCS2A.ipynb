# %% [markdown]
# # Adaptive Contrast Enhancement of Grayscale Images Using Local Statistics and Bilateral Filtering
#
# ### Jave Atanacio Bacsain BSCS-2A (As a requirement for the course of Digital Image Processing - CSAC 225)
# # FINAL PROJECT
#
# - Note that details are already indicated in the document `FP_Bacsain_BSCS2A.pdf`
# - Ran on Python 3.12.0

# %% [markdown]
# # All dataset images processed with PSNR and SSIM results
#
# - Dataset is downloaded from [here](https://figshare.com/articles/dataset/BSD100_Set5_Set14_Urban100/21586188)
#
# This asks for an alpha value to input and outputs processed images in a folder corresponding to its alpha value (e.g., alpha1.0, alpha2.2, etc.) named `outputs` in the same directory

# %%
import cv2
import numpy as np
import os
from skimage import io
from skimage.color import rgb2gray
from skimage.util import img_as_ubyte
from skimage.metrics import peak_signal_noise_ratio as psnr_score
from skimage.metrics import structural_similarity as ssim_score
from glob import glob

"""For each pixel in the image, a small neighborhood around that pixel was considered using a 
blur-based approach to compute local mean and standard deviation. These local statistics guided 
the enhancement by adjusting the pixel intensity relative to the local mean, scaled by a factor 
that decreases in regions with high variation."""

# Parameters
window_size = 15 # 15x15 chosen based on the document (Methods section 3.1: Choice of Window Size)

bilateral_d = 9  # default values from https://docs.opencv.org/4.x/d4/d13/tutorial_py_filtering.html
bilateral_sigmaColor = 75 # default values from https://docs.opencv.org/4.x/d4/d13/tutorial_py_filtering.html
bilateral_sigmaSpace = 75 # default values from https://docs.opencv.org/4.x/d4/d13/tutorial_py_filtering.html
alpha_global = float(input("enter alpha value: ")) # change alpha value here

def local_stats(image, ksize):
    img_f = image.astype(np.float32) / 255.0
    local_mean = cv2.blur(img_f, (ksize, ksize))
    sqr_mean = cv2.blur(img_f**2, (ksize, ksize))
    local_std = np.sqrt(sqr_mean - local_mean**2 + 1e-10)
    return local_mean, local_std

def adaptive_contrast_enhancement(img, ksize):
    local_mean, local_std = local_stats(img, ksize)
    max_std = local_std.max() if local_std.max() > 0 else 1
    norm_std = local_std / max_std
    alpha = alpha_global # ALPHA IS CHANGED HERE
    enhanced = local_mean + alpha * (img/255.0 - local_mean) * (1 - norm_std)
    enhanced = np.clip(enhanced, 0, 1)
    return (enhanced * 255).astype(np.uint8)

def process_image(path, output_dir):
    img = io.imread(path)
    original_gray = img_as_ubyte(rgb2gray(img)) if img.ndim == 3 else img

    enhanced = adaptive_contrast_enhancement(original_gray, window_size)
    filtered = cv2.bilateralFilter(enhanced, bilateral_d, bilateral_sigmaColor, bilateral_sigmaSpace)

    filename = os.path.basename(path)
    save_path = os.path.join(output_dir, filename)
    cv2.imwrite(save_path, filtered)

    # PSNR and SSIM vs original grayscale image
    psnr_val = psnr_score(original_gray, filtered, data_range=255)
    ssim_val = ssim_score(original_gray, filtered, data_range=255)

    print(f"{filename} - PSNR: {psnr_val:.2f} dB | SSIM: {ssim_val:.4f}")
    return psnr_val, ssim_val

def main():
    input_folder = 'BSD100\image_SRF_2'  # downloaded from https://figshare.com/articles/dataset/BSD100_Set5_Set14_Urban100/21586188
    output_folder = f'outputs\\alpha{alpha_global}'
    os.makedirs(output_folder, exist_ok=True)

    image_paths = glob(os.path.join(input_folder, '*.[jp][pn]g'))

    psnr_total, ssim_total = 0.0, 0.0
    count = 0

    for img_path in image_paths:
        psnr_val, ssim_val = process_image(img_path, output_folder)
        psnr_total += psnr_val
        ssim_total += ssim_val
        count += 1

    if count > 0:
        print(f"\nAverage PSNR: {psnr_total / count:.2f} dB")
        print(f"Average SSIM: {ssim_total / count:.4f}")

if __name__ == "__main__":
    main()
# Out:
# <>:59: SyntaxWarning: invalid escape sequence '\i'
# <>:59: SyntaxWarning: invalid escape sequence '\i'
# C:\Users\Jave\AppData\Local\Temp\ipykernel_24948\1362214137.py:59: SyntaxWarning: invalid escape sequence '\i'
#   input_folder = 'BSD100\image_SRF_2'  # downloaded from https://figshare.com/articles/dataset/BSD100_Set5_Set14_Urban100/21586188
# img_001_SRF_2_HR.png - PSNR: 25.71 dB | SSIM: 0.8387
# img_001_SRF_2_LR.png - PSNR: 25.32 dB | SSIM: 0.8384
# img_002_SRF_2_HR.png - PSNR: 28.33 dB | SSIM: 0.9046
# img_002_SRF_2_LR.png - PSNR: 26.37 dB | SSIM: 0.8849
# img_003_SRF_2_HR.png - PSNR: 27.01 dB | SSIM: 0.8761
# img_003_SRF_2_LR.png - PSNR: 27.16 dB | SSIM: 0.8871
# img_004_SRF_2_HR.png - PSNR: 28.40 dB | SSIM: 0.8791
# img_004_SRF_2_LR.png - PSNR: 27.05 dB | SSIM: 0.8668
# img_005_SRF_2_HR.png - PSNR: 27.23 dB | SSIM: 0.8682
# img_005_SRF_2_LR.png - PSNR: 26.35 dB | SSIM: 0.8563
# img_006_SRF_2_HR.png - PSNR: 29.44 dB | SSIM: 0.9113
# img_006_SRF_2_LR.png - PSNR: 27.66 dB | SSIM: 0.8967
# img_007_SRF_2_HR.png - PSNR: 25.81 dB | SSIM: 0.8572
# img_007_SRF_2_LR.png - PSNR: 25.34 dB | SSIM: 0.8505
# img_008_SRF_2_HR.png - PSNR: 25.31 dB | SSIM: 0.8428
# img_008_SRF_2_LR.png - PSNR: 26.25 dB | SSIM: 0.8358
# img_009_SRF_2_HR.png - PSNR: 26.01 dB | SSIM: 0.8670
# img_009_SRF_2_LR.png - PSNR: 24.29 dB | SSIM: 0.8301
# img_010_SRF_2_HR.png - PSNR: 28.71 dB | SSIM: 0.8618
# img_010_SRF_2_LR.png - PSNR: 27.88 dB | SSIM: 0.8504
# img_011_SRF_2_HR.png - PSNR: 23.43 dB | SSIM: 0.8143
# img_011_SRF_2_LR.png - PSNR: 23.05 dB | SSIM: 0.8173
# img_012_SRF_2_HR.png - PSNR: 27.09 dB | SSIM: 0.8175
# img_012_SRF_2_LR.png - PSNR: 25.42 dB | SSIM: 0.7536
# img_013_SRF_2_HR.png - PSNR: 28.48 dB | SSIM: 0.8688
# img_013_SRF_2_LR.png - PSNR: 27.79 dB | SSIM: 0.8397
# img_014_SRF_2_HR.png - PSNR: 27.16 dB | SSIM: 0.8726
# img_014_SRF_2_LR.png - PSNR: 26.71 dB | SSIM: 0.8854
# img_015_SRF_2_HR.png - PSNR: 26.73 dB | SSIM: 0.8515
# img_015_SRF_2_LR.png - PSNR: 26.01 dB | SSIM: 0.8503
# img_016_SRF_2_HR.png - PSNR: 23.69 dB | SSIM: 0.8365
# img_016_SRF_2_LR.png - PSNR: 21.27 dB | SSIM: 0.7877
# img_017_SRF_2_HR.png - PSNR: 31.08 dB | SSIM: 0.8827
# img_017_SRF_2_LR.png - PSNR: 29.83 dB | SSIM: 0.8729
# img_018_SRF_2_HR.png - PSNR: 31.55 dB | SSIM: 0.8940
# img_018_SRF_2_LR.png - PSNR: 30.07 dB | SSIM: 0.8773
# img_019_SRF_2_HR.png - PSNR: 25.21 dB | SSIM: 0.8504
# img_019_SRF_2_LR.png - PSNR: 23.05 dB | SSIM: 0.7982
# img_020_SRF_2_HR.png - PSNR: 25.46 dB | SSIM: 0.8723
# img_020_SRF_2_LR.png - PSNR: 23.87 dB | SSIM: 0.8472
# img_021_SRF_2_HR.png - PSNR: 23.84 dB | SSIM: 0.8651
# img_021_SRF_2_LR.png - PSNR: 22.91 dB | SSIM: 0.8604
# img_022_SRF_2_HR.png - PSNR: 25.38 dB | SSIM: 0.8557
# img_022_SRF_2_LR.png - PSNR: 24.74 dB | SSIM: 0.8574
# img_023_SRF_2_HR.png - PSNR: 27.34 dB | SSIM: 0.8375
# img_023_SRF_2_LR.png - PSNR: 27.62 dB | SSIM: 0.8391
# img_024_SRF_2_HR.png - PSNR: 26.23 dB | SSIM: 0.8585
# img_024_SRF_2_LR.png - PSNR: 25.53 dB | SSIM: 0.8444
# img_025_SRF_2_HR.png - PSNR: 25.56 dB | SSIM: 0.8639
# img_025_SRF_2_LR.png - PSNR: 24.62 dB | SSIM: 0.8678
# img_026_SRF_2_HR.png - PSNR: 27.56 dB | SSIM: 0.9168
# img_026_SRF_2_LR.png - PSNR: 24.41 dB | SSIM: 0.8398
# img_027_SRF_2_HR.png - PSNR: 27.16 dB | SSIM: 0.8478
# img_027_SRF_2_LR.png - PSNR: 25.98 dB | SSIM: 0.8618
# img_028_SRF_2_HR.png - PSNR: 28.94 dB | SSIM: 0.8482
# img_028_SRF_2_LR.png - PSNR: 27.47 dB | SSIM: 0.8182
# img_029_SRF_2_HR.png - PSNR: 27.23 dB | SSIM: 0.8893
# img_029_SRF_2_LR.png - PSNR: 25.00 dB | SSIM: 0.8558
# img_030_SRF_2_HR.png - PSNR: 23.45 dB | SSIM: 0.8889
# img_030_SRF_2_LR.png - PSNR: 23.25 dB | SSIM: 0.8447
# img_031_SRF_2_HR.png - PSNR: 28.57 dB | SSIM: 0.8579
# img_031_SRF_2_LR.png - PSNR: 27.46 dB | SSIM: 0.8002
# img_032_SRF_2_HR.png - PSNR: 22.39 dB | SSIM: 0.7427
# img_032_SRF_2_LR.png - PSNR: 23.38 dB | SSIM: 0.6679
# img_033_SRF_2_HR.png - PSNR: 25.95 dB | SSIM: 0.8417
# img_033_SRF_2_LR.png - PSNR: 24.12 dB | SSIM: 0.7597
# img_034_SRF_2_HR.png - PSNR: 25.32 dB | SSIM: 0.8763
# img_034_SRF_2_LR.png - PSNR: 24.56 dB | SSIM: 0.8477
# img_035_SRF_2_HR.png - PSNR: 29.16 dB | SSIM: 0.8684
# img_035_SRF_2_LR.png - PSNR: 25.61 dB | SSIM: 0.8577
# img_036_SRF_2_HR.png - PSNR: 26.36 dB | SSIM: 0.8620
# img_036_SRF_2_LR.png - PSNR: 24.69 dB | SSIM: 0.8393
# img_037_SRF_2_HR.png - PSNR: 28.20 dB | SSIM: 0.7135
# img_037_SRF_2_LR.png - PSNR: 28.66 dB | SSIM: 0.7077
# img_038_SRF_2_HR.png - PSNR: 27.84 dB | SSIM: 0.8647
# img_038_SRF_2_LR.png - PSNR: 26.55 dB | SSIM: 0.8281
# img_039_SRF_2_HR.png - PSNR: 27.38 dB | SSIM: 0.8497
# img_039_SRF_2_LR.png - PSNR: 26.55 dB | SSIM: 0.8393
# img_040_SRF_2_HR.png - PSNR: 28.11 dB | SSIM: 0.8761
# img_040_SRF_2_LR.png - PSNR: 25.70 dB | SSIM: 0.8430
# img_041_SRF_2_HR.png - PSNR: 25.70 dB | SSIM: 0.8175
# img_041_SRF_2_LR.png - PSNR: 24.50 dB | SSIM: 0.8330
# img_042_SRF_2_HR.png - PSNR: 26.71 dB | SSIM: 0.8719
# img_042_SRF_2_LR.png - PSNR: 25.93 dB | SSIM: 0.8576
# img_043_SRF_2_HR.png - PSNR: 27.96 dB | SSIM: 0.8538
# img_043_SRF_2_LR.png - PSNR: 25.78 dB | SSIM: 0.8378
# img_044_SRF_2_HR.png - PSNR: 26.20 dB | SSIM: 0.8747
# img_044_SRF_2_LR.png - PSNR: 24.73 dB | SSIM: 0.8582
# img_045_SRF_2_HR.png - PSNR: 27.13 dB | SSIM: 0.8795
# img_045_SRF_2_LR.png - PSNR: 27.35 dB | SSIM: 0.8363
# img_046_SRF_2_HR.png - PSNR: 31.40 dB | SSIM: 0.8517
# img_046_SRF_2_LR.png - PSNR: 31.55 dB | SSIM: 0.8575
# img_047_SRF_2_HR.png - PSNR: 23.22 dB | SSIM: 0.8390
# img_047_SRF_2_LR.png - PSNR: 23.34 dB | SSIM: 0.8344
# img_048_SRF_2_HR.png - PSNR: 26.75 dB | SSIM: 0.8568
# img_048_SRF_2_LR.png - PSNR: 26.91 dB | SSIM: 0.8449
# img_049_SRF_2_HR.png - PSNR: 24.36 dB | SSIM: 0.8799
# img_049_SRF_2_LR.png - PSNR: 23.62 dB | SSIM: 0.8724
# img_050_SRF_2_HR.png - PSNR: 31.02 dB | SSIM: 0.8575
# img_050_SRF_2_LR.png - PSNR: 29.73 dB | SSIM: 0.8564
# img_051_SRF_2_HR.png - PSNR: 26.80 dB | SSIM: 0.8522
# img_051_SRF_2_LR.png - PSNR: 26.37 dB | SSIM: 0.8367
# img_052_SRF_2_HR.png - PSNR: 20.50 dB | SSIM: 0.7895
# img_052_SRF_2_LR.png - PSNR: 21.98 dB | SSIM: 0.7895
# img_053_SRF_2_HR.png - PSNR: 31.78 dB | SSIM: 0.8694
# img_053_SRF_2_LR.png - PSNR: 30.48 dB | SSIM: 0.8543
# img_054_SRF_2_HR.png - PSNR: 31.33 dB | SSIM: 0.8174
# img_054_SRF_2_LR.png - PSNR: 31.42 dB | SSIM: 0.8172
# img_055_SRF_2_HR.png - PSNR: 27.05 dB | SSIM: 0.8469
# img_055_SRF_2_LR.png - PSNR: 25.63 dB | SSIM: 0.8348
# img_056_SRF_2_HR.png - PSNR: 24.79 dB | SSIM: 0.8366
# img_056_SRF_2_LR.png - PSNR: 23.10 dB | SSIM: 0.8159
# img_057_SRF_2_HR.png - PSNR: 23.71 dB | SSIM: 0.8306
# img_057_SRF_2_LR.png - PSNR: 24.86 dB | SSIM: 0.8137
# img_058_SRF_2_HR.png - PSNR: 28.03 dB | SSIM: 0.8519
# img_058_SRF_2_LR.png - PSNR: 27.19 dB | SSIM: 0.7776
# img_059_SRF_2_HR.png - PSNR: 31.29 dB | SSIM: 0.8259
# img_059_SRF_2_LR.png - PSNR: 31.07 dB | SSIM: 0.8457
# img_060_SRF_2_HR.png - PSNR: 29.50 dB | SSIM: 0.8395
# img_060_SRF_2_LR.png - PSNR: 28.83 dB | SSIM: 0.8473
# img_061_SRF_2_HR.png - PSNR: 30.99 dB | SSIM: 0.8405
# img_061_SRF_2_LR.png - PSNR: 30.59 dB | SSIM: 0.8318
# img_062_SRF_2_HR.png - PSNR: 28.88 dB | SSIM: 0.8595
# img_062_SRF_2_LR.png - PSNR: 27.23 dB | SSIM: 0.8532
# img_063_SRF_2_HR.png - PSNR: 26.07 dB | SSIM: 0.9029
# img_063_SRF_2_LR.png - PSNR: 21.89 dB | SSIM: 0.8325
# img_064_SRF_2_HR.png - PSNR: 25.65 dB | SSIM: 0.8673
# img_064_SRF_2_LR.png - PSNR: 24.80 dB | SSIM: 0.8247
# img_065_SRF_2_HR.png - PSNR: 25.61 dB | SSIM: 0.8438
# img_065_SRF_2_LR.png - PSNR: 25.15 dB | SSIM: 0.8315
# img_066_SRF_2_HR.png - PSNR: 27.28 dB | SSIM: 0.8736
# img_066_SRF_2_LR.png - PSNR: 26.15 dB | SSIM: 0.8682
# img_067_SRF_2_HR.png - PSNR: 33.37 dB | SSIM: 0.9519
# img_067_SRF_2_LR.png - PSNR: 30.10 dB | SSIM: 0.9270
# img_068_SRF_2_HR.png - PSNR: 23.81 dB | SSIM: 0.8775
# img_068_SRF_2_LR.png - PSNR: 23.05 dB | SSIM: 0.8717
# img_069_SRF_2_HR.png - PSNR: 25.54 dB | SSIM: 0.9094
# img_069_SRF_2_LR.png - PSNR: 24.58 dB | SSIM: 0.8945
# img_070_SRF_2_HR.png - PSNR: 26.83 dB | SSIM: 0.8150
# img_070_SRF_2_LR.png - PSNR: 25.10 dB | SSIM: 0.8176
# img_071_SRF_2_HR.png - PSNR: 29.41 dB | SSIM: 0.8303
# img_071_SRF_2_LR.png - PSNR: 28.78 dB | SSIM: 0.8458
# img_072_SRF_2_HR.png - PSNR: 26.85 dB | SSIM: 0.8533
# img_072_SRF_2_LR.png - PSNR: 26.01 dB | SSIM: 0.8156
# img_073_SRF_2_HR.png - PSNR: 27.47 dB | SSIM: 0.7825
# img_073_SRF_2_LR.png - PSNR: 27.50 dB | SSIM: 0.8023
# img_074_SRF_2_HR.png - PSNR: 26.74 dB | SSIM: 0.8792
# img_074_SRF_2_LR.png - PSNR: 26.23 dB | SSIM: 0.8689
# img_075_SRF_2_HR.png - PSNR: 25.46 dB | SSIM: 0.8458
# img_075_SRF_2_LR.png - PSNR: 23.51 dB | SSIM: 0.8089
# img_076_SRF_2_HR.png - PSNR: 29.23 dB | SSIM: 0.8244
# img_076_SRF_2_LR.png - PSNR: 28.02 dB | SSIM: 0.8229
# img_077_SRF_2_HR.png - PSNR: 26.88 dB | SSIM: 0.8817
# img_077_SRF_2_LR.png - PSNR: 26.68 dB | SSIM: 0.8509
# img_078_SRF_2_HR.png - PSNR: 27.30 dB | SSIM: 0.8591
# img_078_SRF_2_LR.png - PSNR: 25.80 dB | SSIM: 0.8472
# img_079_SRF_2_HR.png - PSNR: 27.14 dB | SSIM: 0.9111
# img_079_SRF_2_LR.png - PSNR: 26.09 dB | SSIM: 0.9071
# img_080_SRF_2_HR.png - PSNR: 30.50 dB | SSIM: 0.8893
# img_080_SRF_2_LR.png - PSNR: 29.84 dB | SSIM: 0.8582
# img_081_SRF_2_HR.png - PSNR: 32.96 dB | SSIM: 0.9165
# img_081_SRF_2_LR.png - PSNR: 31.01 dB | SSIM: 0.9177
# img_082_SRF_2_HR.png - PSNR: 29.45 dB | SSIM: 0.8333
# img_082_SRF_2_LR.png - PSNR: 29.28 dB | SSIM: 0.8350
# img_083_SRF_2_HR.png - PSNR: 24.03 dB | SSIM: 0.8390
# img_083_SRF_2_LR.png - PSNR: 24.75 dB | SSIM: 0.8423
# img_084_SRF_2_HR.png - PSNR: 23.68 dB | SSIM: 0.8377
# img_084_SRF_2_LR.png - PSNR: 25.23 dB | SSIM: 0.8333
# img_085_SRF_2_HR.png - PSNR: 24.29 dB | SSIM: 0.8581
# img_085_SRF_2_LR.png - PSNR: 22.89 dB | SSIM: 0.8352
# img_086_SRF_2_HR.png - PSNR: 25.20 dB | SSIM: 0.8585
# img_086_SRF_2_LR.png - PSNR: 24.57 dB | SSIM: 0.8479
# img_087_SRF_2_HR.png - PSNR: 27.41 dB | SSIM: 0.8355
# img_087_SRF_2_LR.png - PSNR: 26.34 dB | SSIM: 0.8234
# img_088_SRF_2_HR.png - PSNR: 28.49 dB | SSIM: 0.8448
# img_088_SRF_2_LR.png - PSNR: 27.56 dB | SSIM: 0.8410
# img_089_SRF_2_HR.png - PSNR: 28.16 dB | SSIM: 0.8296
# img_089_SRF_2_LR.png - PSNR: 27.66 dB | SSIM: 0.8010
# img_090_SRF_2_HR.png - PSNR: 25.26 dB | SSIM: 0.7682
# img_090_SRF_2_LR.png - PSNR: 23.98 dB | SSIM: 0.5877
# img_091_SRF_2_HR.png - PSNR: 28.47 dB | SSIM: 0.8322
# img_091_SRF_2_LR.png - PSNR: 27.94 dB | SSIM: 0.8213
# img_092_SRF_2_HR.png - PSNR: 27.64 dB | SSIM: 0.8523
# img_092_SRF_2_LR.png - PSNR: 26.40 dB | SSIM: 0.8426
# img_093_SRF_2_HR.png - PSNR: 26.91 dB | SSIM: 0.8779
# img_093_SRF_2_LR.png - PSNR: 27.27 dB | SSIM: 0.8473
# img_094_SRF_2_HR.png - PSNR: 26.17 dB | SSIM: 0.8557
# img_094_SRF_2_LR.png - PSNR: 24.64 dB | SSIM: 0.8367
# img_095_SRF_2_HR.png - PSNR: 26.70 dB | SSIM: 0.8877
# img_095_SRF_2_LR.png - PSNR: 26.14 dB | SSIM: 0.8769
# img_096_SRF_2_HR.png - PSNR: 23.96 dB | SSIM: 0.7332
# img_096_SRF_2_LR.png - PSNR: 27.05 dB | SSIM: 0.7358
# img_097_SRF_2_HR.png - PSNR: 27.38 dB | SSIM: 0.7260
# img_097_SRF_2_LR.png - PSNR: 28.64 dB | SSIM: 0.7530
# img_098_SRF_2_HR.png - PSNR: 25.95 dB | SSIM: 0.8770
# img_098_SRF_2_LR.png - PSNR: 24.59 dB | SSIM: 0.8548
# img_099_SRF_2_HR.png - PSNR: 26.24 dB | SSIM: 0.8162
# img_099_SRF_2_LR.png - PSNR: 24.93 dB | SSIM: 0.8030
# img_100_SRF_2_HR.png - PSNR: 24.82 dB | SSIM: 0.8427
# img_100_SRF_2_LR.png - PSNR: 23.22 dB | SSIM: 0.8132
#
# Average PSNR: 26.59 dB
# Average SSIM: 0.8436

# %% [markdown]
# # With GUI on a single selected photo

# %%
import cv2
import numpy as np
import os
from skimage import io
from skimage.color import rgb2gray
from skimage.util import img_as_ubyte
from skimage.metrics import peak_signal_noise_ratio as psnr_score
from skimage.metrics import structural_similarity as ssim_score
from glob import glob
import tkinter as tk
from tkinter import filedialog

window_size = 15 # 15x15 chosen based on the document (Methods section 3.1: Choice of Window Size)

# Initial parameters for sliders
bilateral_d = 9 # default values from https://docs.opencv.org/4.x/d4/d13/tutorial_py_filtering.html
bilateral_sigmaColor = 75 # default values from https://docs.opencv.org/4.x/d4/d13/tutorial_py_filtering.html
bilateral_sigmaSpace = 75 # default values from https://docs.opencv.org/4.x/d4/d13/tutorial_py_filtering.html
alpha_global = 15  # will represent 1.5 (divide by 10)

def local_stats(image, ksize):
    img_f = image.astype(np.float32) / 255.0
    local_mean = cv2.blur(img_f, (ksize, ksize))
    sqr_mean = cv2.blur(img_f**2, (ksize, ksize))
    local_std = np.sqrt(sqr_mean - local_mean**2 + 1e-10)
    return local_mean, local_std

def adaptive_contrast_enhancement(img, ksize, alpha):
    local_mean, local_std = local_stats(img, ksize)
    max_std = local_std.max() if local_std.max() > 0 else 1
    norm_std = local_std / max_std
    enhanced = local_mean + alpha * (img/255.0 - local_mean) * (1 - norm_std)
    enhanced = np.clip(enhanced, 0, 1)
    return (enhanced * 255).astype(np.uint8)

def process_image(img_gray, alpha, d, sigmaColor, sigmaSpace):
    enhanced = adaptive_contrast_enhancement(img_gray, window_size, alpha)
    filtered = cv2.bilateralFilter(enhanced, d, sigmaColor, sigmaSpace)
    return filtered

def nothing(x):
    pass

def load_image_from_path(path):
    img = io.imread(path)
    if img.ndim == 3:
        img_gray = img_as_ubyte(rgb2gray(img))
    else:
        img_gray = img
    return img_gray, os.path.basename(path)

def main():
    global bilateral_d, bilateral_sigmaColor, bilateral_sigmaSpace, alpha_global

    root = tk.Tk()
    root.geometry('800x600')   #  root window
    root.update()              # Update to apply size
    root.withdraw()            # Hide the root window

    img_path = filedialog.askopenfilename(
        title="Select an image",
        filetypes=[("Image files", "*.png;*.jpg;*.jpeg;*.bmp;*.tiff")]
    )

    if not img_path:
        print("No image selected, exiting.")
        return

    img_gray, img_name = load_image_from_path(img_path)

    cv2.namedWindow('Contrast Enhancement')

    # Create trackbars
    cv2.namedWindow('Contrast Enhancement', cv2.WINDOW_NORMAL)
    cv2.resizeWindow('Contrast Enhancement', 1000, 600)
    cv2.createTrackbar('Alpha x0.1', 'Contrast Enhancement', alpha_global, 50, nothing)
    cv2.createTrackbar('d', 'Contrast Enhancement', bilateral_d, 20, nothing)
    cv2.createTrackbar('S Color', 'Contrast Enhancement', bilateral_sigmaColor, 150, nothing)
    cv2.createTrackbar('S Space', 'Contrast Enhancement', bilateral_sigmaSpace, 150, nothing)

    while True:
        alpha_global = cv2.getTrackbarPos('Alpha x0.1', 'Contrast Enhancement')
        bilateral_d = cv2.getTrackbarPos('d', 'Contrast Enhancement')
        bilateral_sigmaColor = cv2.getTrackbarPos('S Color', 'Contrast Enhancement')
        bilateral_sigmaSpace = cv2.getTrackbarPos('S Space', 'Contrast Enhancement')

        if bilateral_d <= 0:
            bilateral_d = 1
        if bilateral_d % 2 == 0:
            bilateral_d += 1
            if bilateral_d > 21:
                bilateral_d = 21

        alpha = max(0.1, min(alpha_global / 10, 5.0))

        processed = process_image(img_gray, alpha, bilateral_d, bilateral_sigmaColor, bilateral_sigmaSpace)

        psnr_val = psnr_score(img_gray, processed, data_range=255)
        ssim_val = ssim_score(img_gray, processed, data_range=255)

        original_bgr = cv2.cvtColor(img_gray, cv2.COLOR_GRAY2BGR)
        processed_bgr = cv2.cvtColor(processed, cv2.COLOR_GRAY2BGR)
        combined = np.hstack((original_bgr, processed_bgr))

        height, width = combined.shape[:2]
        black_strip = np.zeros((50, width, 3), dtype=np.uint8)

        cv2.putText(black_strip, f'Original: {img_name}', (10, 20), cv2.FONT_HERSHEY_SIMPLEX, 0.6, (255,255,255), 1)
        cv2.putText(black_strip, f'Processed PSNR: {psnr_val:.2f} dB', (10, 40), cv2.FONT_HERSHEY_SIMPLEX, 0.6, (255,255,255), 1)
        cv2.putText(black_strip, f'Processed SSIM: {ssim_val:.4f}', (width//2 + 10, 40), cv2.FONT_HERSHEY_SIMPLEX, 0.6, (255,255,255), 1)
        cv2.putText(black_strip, f'Alpha: {alpha:.2f}', (width//2 + 10, 20), cv2.FONT_HERSHEY_SIMPLEX, 0.6, (255,255,255), 1)

        final_img = np.vstack((combined, black_strip))

        cv2.imshow('Contrast Enhancement', final_img)

        key = cv2.waitKey(50) & 0xFF
        if key == 27:
            break

    cv2.destroyAllWindows()

if __name__ == "__main__":
    main()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[31], line 124
#     121     cv2.destroyAllWindows()
#     123 if __name__ == "__main__":
# --> 124     main()
#
# Cell In[31], line 117, in main()
#     113 final_img = np.vstack((combined, black_strip))
#     115 cv2.imshow('Contrast Enhancement', final_img)
# --> 117 key = cv2.waitKey(50) & 0xFF
#     118 if key == 27:
#     119     break
#
# KeyboardInterrupt:
